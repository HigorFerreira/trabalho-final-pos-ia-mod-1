# %%
import pandas as pd
import numpy as np
from modulos.data_load import load

# %%
df = load('AAVEBTC')
df
# Out:
#                 unix                date    symbol      open      high  \
# 41405  1602288000000 2020-10-10 00:00:00  AAVE/BTC  0.003800  0.009801
# 41404  1602352800000 2020-10-10 18:00:00  AAVE/BTC  0.003800  0.003800
# 41403  1602356400000 2020-10-10 19:00:00  AAVE/BTC  0.003800  0.003800
# 41402  1602360000000 2020-10-10 20:00:00  AAVE/BTC  0.003800  0.003800
# 41401  1602363600000 2020-10-10 21:00:00  AAVE/BTC  0.003800  0.003800
# ...              ...                 ...       ...       ...       ...
# 4      1751400000000 2025-07-01 20:00:00  AAVE/BTC  0.002398  0.002398
# 3      1751403600000 2025-07-01 21:00:00  AAVE/BTC  0.002398  0.002398
# 2      1751407200000 2025-07-01 22:00:00  AAVE/BTC  0.002398  0.002398
# 1      1751410800000 2025-07-01 23:00:00  AAVE/BTC  0.002398  0.002398
# 0      1751414400000 2025-07-02 00:00:00  AAVE/BTC  0.002398  0.002398
#
#             low     close  Volume AAVE  Volume BTC  buyTakerAmount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41406 entries, 0 to 41405
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   unix              41406 non-null  int64
#  1   date              41406 non-null  datetime64[ns]
#  2   symbol            41406 non-null  object
#  3   open              41406 non-null  float64
#  4   high              41406 non-null  float64
#  5   low               41406 non-null  float64
#  6   close             41406 non-null  float64
#  7   Volume AAVE       41406 non-null  float64
#  8   Volume BTC        41406 non-null  float64
#  9   buyTakerAmount    41406 non-null  float64
#  10  buyTakerQuantity  41406 non-null  float64
#  11  tradeCount        41406 non-null  int64
#  12  weightedAverage   41406 non-null  float64
# dtypes: datetime64[ns](1), float64(9), int64(2), object(1)
# memory usage: 4.1+ MB
