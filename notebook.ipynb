# %%
import pandas as pd
import numpy as np
from modulos.data_load import load

# %%
df = load('AAVEUSDT')
df
# Out:
#                 unix                 date     symbol       open       high  \
# 0      1751500800000  2025-07-03 00:00:00  AAVE/USDT  276.39000  278.32000
# 1      1751497200000  2025-07-02 23:00:00  AAVE/USDT  279.77000  281.01000
# 2      1751493600000  2025-07-02 22:00:00  AAVE/USDT  281.10000  281.81000
# 3      1751490000000  2025-07-02 21:00:00  AAVE/USDT  279.93000  281.81000
# 4      1751486400000  2025-07-02 20:00:00  AAVE/USDT  279.68000  280.44000
# ...              ...                  ...        ...        ...        ...
# 41455  1602255600000  2020-10-09 15:00:00  AAVE/USDT   25.15312   25.15312
# 41456  1602252000000  2020-10-09 14:00:00  AAVE/USDT   25.15312   25.15312
# 41457  1602248400000  2020-10-09 13:00:00  AAVE/USDT   25.15312   25.15312
# 41458  1602244800000  2020-10-09 12:00:00  AAVE/USDT   25.15312   25.15312
# 41459  1602201600000  2020-10-09 00:00:00  AAVE/USDT   25.15312   55.00007
#
# ...
